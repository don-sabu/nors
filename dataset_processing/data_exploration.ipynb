# %%
import pandas as pd
import os

# %%
path = os.listdir("data/")
path

# %%
train = pd.read_csv("data/"+path[0]+"/train.csv")

# %%
train

# %%
train.loc[train['product_id'] == 25407]

# %%
dict = {}
for index, row in train.iterrows():
    dict[row['product_id']] = row['name']

# %%
dict

# %%
len(dict)

# %%
for index, row in train.iterrows():
    if  dict[row['product_id']] != row['name']:
        print(dict[row['product_id']]," - ", row['name'])

# %%
d= {1: 'dfs',2:'sdf',3:'bvzcxv'}
list(d.keys())

# %%
list(d.values())

# %%
import pandas as pd

# %%
def check_products():
    products = pd.read_csv('products.csv')
    users = os.listdir("data/")
    user_name = []
    index_no = []
    order_id = []
    product_id = []
    for user in tqdm(users, desc="Processing Users"):

        train = pd.read_csv("data/" + user + "/train.csv")
        test = pd.read_csv("data/" + user + "/test.csv")
        for index, row in train.iterrows():
            if  dict[row['product_id']] != row['name']:
                user_name.append("user")
                index_no.append(index)
                order_id.append(dict[row['order_id']])
                product_id.append(dict[row['product_id']])
        for index, row in test.iterrows():
            if  dict[row['product_id']] != row['name']:
                user_name.append("user")
                index_no.append(index)
                order_id.append(dict[row['order_id']])
                product_id.append(dict[row['product_id']])
    data = {"user name" : user_name,
            "index" : index_no,
            "order ID" : order_id,
            "product id" : product_id}

# %%
data = pd.read_csv('products.csv')

# %%
data
# Out:
#           id                                               name
# 0      23645  Refrigerated fruit juice - see varieties in store
# 1      32406                           Hygienic buffers - Pearl
# 2      45866                                 Disinfecting wipes
# 3      25407                                              mango
# 4      11777                                            Laundry
# ...      ...                                                ...
# 17563  48072                                           tomatoes
# 17564  48073                                           Pipeline
# 17565  48075          Sweet Condensed Milk - President's Choice
# 17566  48179                     Acetaminophen - Regular 325 mg
# 17567  48180                                 Flavored pale tuna
#
# [17568 rows x 2 columns]

# %%
product = data.loc[data['id']==48072,'name'].values[0]

# %%
type(product)
# Out:
# str

# %%
print(product)
# Out:
# tomatoes

# %%
data.to_dict(orient='list')
# Out:
# {'id': [23645,
#   32406,
#   45866,
#   25407,
#   11777,
#   7559,
#   44830,
#   41500,
#   27845,
#   17871,
#   28939,
#   2809,
#   3145,
#   47337,
#   3466,
#   9071,
#   18960,
#   21137,
#   18229,
#   37817,
#   15261,
#   47766,
#   3390,
#   44359,
#   36062,
#   15850,
#   47167,
#   19519,
#   33787,
#   16043,
#   27642,
#   17948,
#   34255,
#   24852,
#   42265,
#   30440,
#   43935,
#   4957,
#   36554,
#   10418,
#   31650,
#   21709,
#   13829,
#   19980,
#   31678,
#   24615,
#   38747,
#   43901,
#   15005,
#   12845,
#   30841,
#   11741,
#   34584,
#   37042,
#   39764,
#   13213,
#   36676,
#   17566,
#   3599,
#   12811,
#   32667,
#   19778,
#   25753,
#   12384,
#   44156,
#   15392,
#   46892,
#   33825,
#   43889,
#   18765,
#   39108,
#   1408,
#   40199,
#   20899,
#   6587,
#   7780,
#   38884,
#   10305,
#   35184,
#   43148,
#   38275,
#   5826,
#   14870,
#   28397,
#   13629,
#   19019,
#   39973,
#   9513,
#   403,
#   39693,
#   1377,
#   35336,
#   9604,
#   48486,
#   40063,
#   17600,
#   36117,
#   34160,
#   47209,
#   6571,
#   5006,
#   23862,
#   6849,
#   49387,
#   18698,
#   36848,
#   14379,
#   31101,
#   11190,
#   16290,
#   13588,
#   16254,
#   42536,
#   27117,
#   25904,
#   48742,
#   30683,
#   21206,
#   33919,
#   21131,
#   6388,
#   46923,
#   27180,
#   10644,
#   23461,
#   23203,
#   7897,
#   28289,
#   28199,
#   24165,
#   13535,
#   28379,
#   24838,
#   8573,
#   26029,
#   23275,
#   34668,
#   28985,
#   9020,
#   29891,
#   15090,
#   35089,
#   9810,
#   45562,
#   15153,
#   21883,
#   38777,
#   27104,
#   29408,
#   26182,
#   16135,
#   28411,
#   4054,
#   21903,
#   44354,
#   33741,
#   11215,
#   23770,
#   6101,
#   36870,
#   36379,
#   9230,
#   12854,
#   33816,
#   11105,
#   47465,
#   15078,
#   28278,
#   31343,
#   6604,
#   32385,
#   3066,
#   40716,
#   35504,
#   9480,
#   2405,
#   25199,
#   2421,
#   28204,
#   24527,
#   24303,
#   21955,
#   19097,
#   43122,
#   31997,
#   18370,
#   703,
#   33620,
#   8424,
#   18376,
#   29398,
#   19706,
#   9210,
#   21347,
#   2966,
#   13838,
#   44580,
#   7041,
#   8514,
#   17309,
#   48071,
#   23338,
#   9507,
#   32560,
#   11041,
#   29350,
#   21938,
#   37436,
#   26987,
#   7948,
#   39275,
#   13853,
#   16445,
#   38124,
#   2962,
#   35696,
#   44010,
#   42254,
#   11844,
#   13053,
#   2439,
#   3522,
#   10157,
#   13431,
#   15112,
#   43294,
#   39566,
#   22034,
#   12544,
#   42469,
#   13780,
#   40180,
#   27828,
#   16743,
#   21288,
#   42701,
#   48364,
#   25256,
#   24506,
#   9444,
#   44501,
#   35221,
#   32003,
#   46129,
#   16174,
#   49520,
#   40232,
#   16737,
#   30407,
#   1808,
#   15689,
#   45960,
#   14689,
#   7769,
#   13194,
#   25133,
#   48057,
#   20277,
#   27735,
#   8006,
#   11768,
#   44182,
#   12644,
#   30855,
#   27620,
#   26487,
#   2225,
#   42650,
#   41690,
#   18594,
#   3485,
#   20785,
#   49140,
#   6385,
#   39815,
#   29616,
#   20738,
#   28671,
#   27243,
#   48047,
#   31187,
#   8368,
#   35065,
#   22624,
#   38259,
#   40067,
#   24617,
#   15703,
#   5760,
#   42458,
#   34256,
#   577,
#   28342,
#   34282,
#   15285,
#   18371,
#   45061,
#   25309,
#   20705,
#   28137,
#   49424,
#   39201,
#   15063,
#   24970,
#   48498,
#   48812,
#   47728,
#   25758,
#   29316,
#   10132,
#   47258,
#   32463,
#   26034,
#   38311,
#   42447,
#   26248,
#   1612,
#   48923,
#   1751,
#   37947,
#   27522,
#   36389,
#   7285,
#   37050,
#   25190,
#   3464,
#   30945,
#   14814,
#   29980,
#   24866,
#   13396,
#   23752,
#   44508,
#   31986,
#   19111,
#   36853,
#   45832,
#   31326,
#   24929,
#   25588,
#   4086,
#   26278,
#   35140,
#   2187,
#   5462,
#   42617,
#   38920,
#   49353,
#   43086,
#   42341,
#   9467,
#   49074,
#   12046,
#   27226,
#   3334,
#   26271,
#   21198,
#   18304,
#   12228,
#   34557,
#   18849,
#   44035,
#   15767,
#   5073,
#   49260,
#   32927,
#   12380,
#   42333,
#   47216,
#   14742,
#   39661,
#   43597,
#   32782,
#   31392,
#   46143,
#   48182,
#   44337,
#   35855,
#   40778,
#   1516,
#   38159,
#   2050,
#   27043,
#   42858,
#   42444,
#   48629,
#   48874,
#   26738,
#   10999,
#   16481,
#   4462,
#   33113,
#   28230,
#   48706,
#   17640,
#   5971,
#   12034,
#   36716,
#   40390,
#   47601,
#   45099,
#   13819,
#   22927,
#   5575,
#   15528,
#   30967,
#   41711,
#   23749,
#   9413,
#   25890,
#   9366,
#   15649,
#   10314,
#   46709,
#   19049,
#   42969,
#   4896,
#   18634,
#   37565,
#   8048,
#   21577,
#   16507,
#   31778,
#   47937,
#   26771,
#   40113,
#   4232,
#   46380,
#   33095,
#   49416,
#   47585,
#   10549,
#   27315,
#   42274,
#   756,
#   47783,
#   9989,
#   15816,
#   32839,
#   39276,
#   40756,
#   37630,
#   2077,
#   67,
#   39557,
#   8311,
#   45747,
#   17341,
#   26209,
#   33731,
#   37880,
#   30753,
#   4541,
#   7933,
#   14043,
#   13470,
#   7293,
#   5359,
#   35496,
#   19875,
#   29387,
#   24190,
#   21663,
#   32466,
#   30919,
#   16226,
#   8414,
#   24955,
#   23126,
#   25464,
#   22451,
#   23650,
#   4298,
#   45372,
#   16709,
#   20704,
#   27272,
#   17003,
#   47570,
#   45761,
#   46979,
#   27126,
#   41819,
#   31423,
#   38212,
#   5224,
#   46736,
#   1376,
#   10814,
#   7556,
#   21019,
#   3526,
#   29182,
#   35091,
#   10423,
#   16920,
#   41003,
#   27897,
#   4445,
#   42840,
#   33216,
#   39984,
#   24084,
#   20607,
#   37002,
#   26568,
#   28080,
#   4039,
#   30257,
#   37717,
#   33718,
#   21567,
#   12258,
#   20794,
#   35951,
#   9755,
#   27966,
#   13857,
#   29646,
#   24673,
#   26063,
#   26803,
#   2198,
#   15498,
#   8352,
#   2335,
#   13810,
#   48183,
#   6506,
#   46060,
#   3974,
#   920,
#   9499,
#   18906,
#   36906,
#   29103,
#   19240,
#   5296,
#   42671,
#   46692,
#   20781,
#   20428,
#   37696,
#   3556,
#   9474,
#   37354,
#   17731,
#   24283,
#   39890,
#   32407,
#   44329,
#   23273,
#   46184,
#   49155,
#   48112,
#   16137,
#   10343,
#   38730,
#   6891,
#   36129,
#   17260,
#   26905,
#   46058,
#   4391,
#   4332,
#   36643,
#   13027,
#   12562,
#   27365,
#   15591,
#   42643,
#   15333,
#   881,
#   39017,
#   32665,
#   11758,
#   27105,
#   18352,
#   20608,
#   28811,
#   2988,
#   38368,
#   8926,
#   10251,
#   40287,
#   188,
#   9554,
#   16797,
#   16349,
#   11193,
#   7905,
#   22308,
#   27380,
#   8710,
#   18200,
#   4600,
#   49589,
#   3050,
#   15207,
#   10310,
#   7500,
#   37158,
#   32865,
#   4898,
#   4037,
#   16518,
#   45566,
#   8755,
#   23181,
#   28806,
#   42283,
#   48035,
#   41637,
#   37464,
#   47734,
#   29987,
#   16038,
#   10210,
#   23043,
#   45249,
#   48114,
#   32734,
#   31618,
#   7807,
#   6664,
#   32096,
#   35997,
#   24622,
#   43772,
#   21124,
#   19354,
#   11404,
#   12986,
#   37865,
#   36034,
#   19022,
#   4799,
#   35909,
#   49495,
#   34257,
#   47866,
#   20526,
#   25017,
#   7639,
#   11350,
#   43988,
#   22326,
#   3648,
#   1631,
#   19054,
#   35508,
#   24643,
#   38448,
#   21743,
#   37787,
#   15556,
#   4401,
#   14191,
#   45229,
#   15348,
#   14010,
#   48352,
#   40299,
#   3593,
#   41080,
#   32156,
#   2748,
#   32446,
#   42557,
#   35004,
#   14898,
#   34423,
#   3172,
#   35522,
#   25860,
#   7399,
#   6438,
#   12962,
#   1483,
#   39712,
#   17099,
#   49633,
#   37727,
#   7467,
#   14992,
#   37892,
#   38563,
#   34358,
#   5423,
#   6673,
#   769,
#   17622,
#   20528,
#   11300,
#   5309,
#   29418,
#   44008,
#   39832,
#   44761,
#   23368,
#   21334,
#   23756,
#   16997,
#   28628,
#   33805,
#   7785,
#   43691,
#   16593,
#   22831,
#   36206,
#   40878,
#   33694,
#   6948,
#   10892,
#   3856,
#   29752,
#   18467,
#   42828,
#   9458,
#   40020,
#   27772,
#   15824,
#   21908,
#   41551,
#   12289,
#   41215,
#   28479,
#   36481,
#   17791,
#   38273,
#   4674,
#   49508,
#   37999,
#   8089,
#   11182,
#   16209,
#   46994,
#   39997,
#   24422,
#   11440,
#   44632,
#   32445,
#   14409,
#   32047,
#   35565,
#   46996,
#   8468,
#   11210,
#   16535,
#   27555,
#   9047,
#   53,
#   49338,
#   4847,
#   31486,
#   5947,
#   3847,
#   39083,
#   36191,
#   10116,
#   33914,
#   46294,
#   2593,
#   23405,
#   47626,
#   15079,
#   31701,
#   40294,
#   28741,
#   3754,
#   33654,
#   1330,
#   4217,
#   25506,
#   7179,
#   2383,
#   38376,
#   37036,
#   30175,
#   31915,
#   30505,
#   3168,
#   39657,
#   22808,
#   49481,
#   23200,
#   5251,
#   47222,
#   39758,
#   47145,
#   22263,
#   35055,
#   13637,
#   150,
#   18569,
#   3128,
#   31378,
#   1263,
#   16508,
#   30471,
#   4664,
#   23728,
#   48220,
#   9593,
#   48086,
#   36123,
#   19705,
#   1541,
#   2519,
#   21653,
#   40058,
#   38426,
#   48642,
#   21143,
#   21298,
#   13365,
#   43352,
#   48437,
#   28937,
#   5670,
#   38796,
#   7616,
#   8246,
#   21661,
#   37520,
#   25387,
#   14947,
#   14297,
#   45977,
#   26505,
#   14985,
#   18709,
#   28261,
#   10209,
#   45204,
#   15539,
#   9871,
#   28715,
#   14267,
#   9825,
#   2852,
#   45094,
#   49248,
#   737,
#   3518,
#   49271,
#   37511,
#   4796,
#   10978,
#   15519,
#   13948,
#   11984,
#   23330,
#   17744,
#   29007,
#   24893,
#   40350,
#   46521,
#   34619,
#   33512,
#   17584,
#   43629,
#   45762,
#   20181,
#   17434,
#   23456,
#   45362,
#   33215,
#   45863,
#   40104,
#   5334,
#   44626,
#   3516,
#   46667,
#   21953,
#   24830,
#   13176,
#   43390,
#   14332,
#   7632,
#   49051,
#   4105,
#   2449,
#   24508,
#   19609,
#   30031,
#   48178,
#   46109,
#   13599,
#   8265,
#   36910,
#   27045,
#   23130,
#   13378,
#   34311,
#   40761,
#   47025,
#   44949,
#   14403,
#   2110,
#   4100,
#   37237,
#   19364,
#   40356,
#   29912,
#   17326,
#   9175,
#   5680,
#   32755,
#   8103,
#   12438,
#   48679,
#   37646,
#   481,
#   6467,
#   26105,
#   17140,
#   20600,
#   47501,
#   15765,
#   1267,
#   41750,
#   43891,
#   3861,
#   7542,
#   22825,
#   47658,
#   3607,
#   15937,
#   37215,
#   30182,
#   23537,
#   13646,
#   4839,
#   33401,
#   38005,
#   29509,
#   8518,
#   34582,
#   42556,
#   47325,
#   31662,
#   33222,
#   4797,
#   33274,
#   21380,
#   35264,
#   44414,
#   22340,
#   48473,
#   42154,
#   5337,
#   35737,
#   11896,
#   46953,
#   17183,
#   45655,
#   16363,
#   45700,
#   35267,
#   47371,
#   49408,
#   5020,
#   994,
#   47202,
#   49411,
#   32864,
#   22456,
#   13205,
#   4557,
#   24964,
#   25886,
#   32500,
#   10570,
#   20736,
#   31467,
#   10044,
#   27460,
#   3844,
#   10246,
#   39121,
#   35099,
#   48813,
#   6815,
#   36186,
#   40041,
#   5152,
#   27992,
#   27848,
#   42117,
#   41877,
#   25489,
#   20578,
#   28304,
#   14331,
#   19663,
#   16636,
#   47033,
#   25998,
#   42811,
#   ...],
#  'name': ['Refrigerated fruit juice - see varieties in store',
#   'Hygienic buffers - Pearl',
#   'Disinfecting wipes',
#   'mango',
#   'Laundry',
#   'Chewing gum',
#   'Spread',
#   'feta cheese',
#   'Capillary Products - Fruits',
#   'Cabbage salad - * Bonus 15 points M',
#   'Chocolate milk - Quebec - See in store varieties',
#   'Disinfecting wipes',
#   'Ice Cream With Vanilla',
#   'Acetaminophen - Complete - Cold, Cough and Influenza',
#   'Bars - Maxi Max',
#   'Charcuterie, Bologna',
#   'Ice Sweets - Drumstick - View Varieties in-store',
#   'Chips - Saturday, November 16th only - Limit of 4',
#   'sports drink',
#   'Greek Yogurt - * 100 Points Bonus M In Buy 2',
#   'English muffins',
#   'Pale tuna Listao',
#   'Green Organic Beard - US',
#   'Drain opener',
#   'Frozen Pork Back Côtes - Save $ 5.11',
#   'Fruit Drink - Unnamed - See Varieties In Store',
#   'Ice Cream - Real Cream - See Varieties In Store',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Frozen pork back ribs',
#   'Marmalade - Buy 2 and get 1 FREE 1 peanut butter (500 g)',
#   'Ice cream bars - see varieties in store',
#   'Acetaminophen - Regular 325 mg',
#   'Frozen Calzones - See Varieties in-store',
#   'Toothpaste - Sensitive - Sunday 29th and Monday 30 December only - Limit of 4 - $ 2.99 per additional item',
#   'Powder preparation for infants - see varieties in store',
#   'Vegetable potato chips - See varieties in store',
#   'Bagelwichs - Best Prices year',
#   'Nibrants - See Varieties In store',
#   'Disinfecting wipes',
#   "Frozen Dinner - O 'Sole Mio - See Varieties In Store",
#   'Flavored milk',
#   'Jam - Pure - View Varieties in store',
#   'Cheese - 40% off',
#   'Refrigerated dessert',
#   "Large Frozen Cooked Foods - President's Choice - See Varieties In-store",
#   'Juices - Nutrisource',
#   'Refrigerated dessert',
#   'Chocolate',
#   'Honey',
#   'Disinfecting wipes',
#   'minced pork',
#   'Chocolate milk 1%',
#   'Potatoes - Quebec',
#   'CREAM 10%',
#   'Frozen duck - Category Utility',
#   'Coffee Capsules - Nabob - View Varieties In Store',
#   'White eggs, big caliber - lower price of the year',
#   'salmon, net, fresh',
#   'Refrigerated dessert',
#   'Fruit Drink - See Varieties In Store',
#   'Deodorant',
#   'Biological mature - the United States and / or Mexico',
#   'Yogurt - creamy - see varieties in store',
#   'Refrigerated orange juice, with pulps - View varieties in store - Limit of 4 - $ 3.99 per additional item',
#   'Toothbrush - Extra Clean - Saturday 15 and Sunday 16 September only - Limit of 4 - 99 ¢ The rest of the week or by article out of bound',
#   'Seasoned fish fillets, frozen - See in store varieties',
#   'Cotton swabs',
#   'Frozen waffles - EGGO',
#   'Crunchy bars - Special K',
#   'Ice Cream With Vanilla',
#   'Licorice - NIBS - See Varieties in-store',
#   'Bocconcini Cheese (Fresh Mozzarella)',
#   'Ice Cream With Vanilla',
#   'Margarine with lawyer oil',
#   'Collagen - Original Formula',
#   'Beer in Extra cans - * Bonus 50 Points M',
#   'Hygienic buffers - Pearl',
#   'Toilet paper - Saturday, February 16th only - Limit of 4 - $ 5.99 The rest of the week or by article out of bounds',
#   'PEKOE orange tea in sachets',
#   'Toothbrush - Twister - Saturday 17 and Sunday 18 August only.- Limit of 4 - 99 ¢ The rest of the week or by item outside the limit',
#   'Frozen thin crust pizza - rustico',
#   'Crunchy peanut butter',
#   'Cookies - Choco',
#   'White potatoes - from Quebec',
#   "Organic Cereals - Nature's Path - See in store varieties",
#   'Black chocolate snack - BARKTHINS - * BONUS 20 POINTS M',
#   'Biological Hass Lawyer - Mexico',
#   'Cereal - Special K',
#   'Antiperspirant vaporizer',
#   'Fruit juice',
#   'Pure honey',
#   'Grain Coffee - See Varieties in Store - * Bonus 45 Points M',
#   "Maple Syrup - President's Choice",
#   'Crunchy bars - Special K',
#   'Scented oil - save $ 1 more when buying 1 product with a good-discount in store',
#   'Mined with ham',
#   'Italian tomatoes',
#   'Cookies - weather - see varieties in store',
#   'Beans - See Varieties In Store',
#   'Garlic Sticks - Giuseppe',
#   'Antiperspirants - see varieties in store',
#   'Apple Compote - Free',
#   'U Fitness buffers',
#   'Wholesale whole water melon without glitches - the United States and / or Mexico',
#   'Target - Max - Saturday 27 and Sunday, July 28th only.- Limit of 4 - $ 5.99 The rest of the week or by item outside the limit',
#   'Lemons',
#   'Frozen meal - Hungry-man - See in store varieties',
#   'Yellow Asian Pear - China',
#   'Fresh stuffed pasta',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Almond Drink - Natur-A',
#   'Refrigerated dessert',
#   'Sliced White Mushrooms - Canada',
#   'Almond Butter - Blue Menu',
#   'Chopped chicken - blue menu',
#   'Turkey skewers with vegetables',
#   'Chicken spread',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Toothbrush - twister - see varieties in store',
#   'Frozen pastry - Toaster Strudel - See in store varieties',
#   'Frozen pastry - Toaster Strudel - See in store varieties',
#   'Greenhouse Orange Peppers - Imported',
#   'Mesclun (mixed lettuce)',
#   'Hygienic buffers - Pearl',
#   'Ice Cream - Häagen-Dazs',
#   'Refrigerated fruit drink - see varieties in store',
#   'Apple Compote - Free',
#   'Ice Cream With Vanilla',
#   'Fruit snack - fruit',
#   "Jam - Smucker's",
#   'Bars - see varieties in store',
#   'PREPARATION FOR INFANTONS - MORE START More',
#   'Natural peanut butter',
#   'Cats Food - Friskies - View Varieties in-store',
#   'Crunchy bars - Special K',
#   'Textile softening in leaves',
#   'Instant Rice - See Varieties In Store',
#   'Organic NAVEL ORANGES, WITHOUT PENSION - United States - * Bonus 10 Points M',
#   'Frozen chicken breast fillets',
#   'Vitamin C - 500 mg',
#   'Pasta - See Varieties In stock',
#   "Pork Back Côtes - Lou's",
#   'Ice Sweets - Drumstick',
#   'Pellets - see varieties in store',
#   "Honey - President's Choice - See Varieties In Store",
#   'Revitalizer - * Bonus 25 Points M',
#   'Litchis - Imported',
#   'Cookies - Save $ 1 In addition to the purchase of 2 products with a good-discount in store',
#   'sugar peas snap',
#   'English muffins',
#   'Whipped cream cheese - Philadelphia',
#   'Frozen waffles - EGGO',
#   'Tipper - Tiger - Limit of 4 - $ 6.99 per additional item',
#   'Table towels - * Bonus 15 points M',
#   'Vitamin C - 500 mg',
#   "Cheese Cake - President's Choice - See Varieties In Store",
#   'Perfume enhancer for laundry',
#   'Licorice - Super Nibs - See Varieties In Store',
#   'Jam - See Variety In Store',
#   'Organic yellow onions',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Frozen Whole Duck - Brome Lake - Category A',
#   'Softening textile',
#   'Beets',
#   'Frozen breast chest nuggets - * Get 100 air miles from buying 3',
#   'Barres - Taste Mountain',
#   'Eye Tracer - Infallible',
#   'Eye Tracer - Infallible',
#   'Laundry Detergent - Pods',
#   'Half Smoked Hair Boneless - Toupie Genre',
#   'Music squash - in the United States',
#   'Laundry Detergent - Pods',
#   'Kaiser breads',
#   'Craped Chicken - Packled Swimming',
#   'Sure Cream - * Bonus 15 Points M',
#   'Frozen breaded chicken nuggets - pub recipe',
#   'mango',
#   'Cats Food - Cat Chow - Save $ 1.50',
#   'Capillary dye - image',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'kaiser bread',
#   'Licorice',
#   'Red or White Wine - $ 6 Discount on Viniers 3-4 L - See Varieties in-store',
#   'Orange juice',
#   'Milk 2% - Finely filtered',
#   'Hand cream',
#   'Body cleaner',
#   'Ice Cream With Vanilla',
#   'Ice Cream With Vanilla',
#   'Cookies - Maple Leaf - Buy 2 and get 1 free marshmall bag (454 g), worth $ 2.49.',
#   'Organic Ground Coffee - See Varieties In Store',
#   'Mozzarelissima bar',
#   'Ice Cream With Vanilla',
#   'paninis',
#   'Biscuits - Bear legs - see varieties in store',
#   'pineapple',
#   'vegetable shortening',
#   'Cookies - Choco',
#   'Pickles',
#   'Rouge delicious apples - from the United States',
#   'Tomatoes - Accents - See varieties in store',
#   'Cookies - Goglu',
#   'rhubarbes',
#   'Fresh cheese - Minigo - View Varieties in store',
#   'Fruit snacks - fruit-o-long',
#   'Refrigerated Juice Mix - Nature Collection',
#   'Ice cream - Cremerie style - See in store varieties',
#   'Disinfecting wipes',
#   "Baby Cookies - Farley's - See Varieties In Store",
#   'Wafers - see varieties in store',
#   "Rice - Uncle Ben's - Save $ 1 - * $ 6.49 Without Coupon - Limit of 1 Coupon by Purchase, By Customer",
#   'Peanut Butter - All Natural',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Salmon',
#   'Baby Food - See Varieties In Store',
#   'Peanut Butter',
#   'Fruit Drink - View Varieties In Store',
#   'Submarine breads',
#   'Yogurt - Source - See Varieties in-store',
#   'Refrigerated dessert',
#   'Antiperspirants - see varieties in store',
#   'Refrigerated Cranberry Cocktail - Saturday, July 14th Only - Limit of 4 - $ 3.49 The rest of the week or by item outside the limit',
#   'Batteries - Lower price of the year',
#   'Honey',
#   'Vegetable Cocktail - Garden Cocktail',
#   'Peanut Butter - All Natural',
#   'Brown eggs - Gros Caliber',
#   'Peanut Butter - See Varieties In Store',
#   'Tomato Pastry - See Varieties In Store',
#   'Cheese sticks',
#   'Babies Bok Choy',
#   'Ice Sweets - Drumstick - View Varieties in-store',
#   'Frozen thin crust pizza - rustico',
#   "Frozen meal - Marie Callender's",
#   'Tea - Saturday 18th and Sunday 19 January alone - Limit of 4 - $ 4.99 per additional item - $ 4.99 The rest of the week',
#   'Tissue Paper - Unnamed - Saturday 28th and Sunday 29 September only.- limit of 4 - $ 4.99 the rest of the week or by item outside the limit',
#   'Gas Drink - Coke - See Varieties in Store - 50% off',
#   'Boneless turkey chest without skin - from Quebec',
#   'Toothbrush - Extra Clean - Saturday 5th and Sunday January 6th - Limit of 4 - 99 ¢ The rest of the week or by article out of bounds',
#   'Hygienic paper - Fluff',
#   'Antiperspirants - see varieties in store',
#   'Sardines',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Plastic Film - Unnamed',
#   'Energy Bar - See Varieties In Store',
#   'Batteries - max',
#   'Soup Mix - Lipton',
#   'Preparation for infants A + 2',
#   'Mushrooms Carnesses - Canada and / or the United States',
#   'Honey - Unnamed',
#   'Frozen Pizza - Trabec',
#   'Biological hummus - humm!- View varieties in store',
#   "Candy - Werther's original",
#   'Artesian water',
#   'Refrigerated dessert',
#   'Hand cream',
#   "Cheese - Sir Laurier d'Arthabaska",
#   'Green cabbage - from Quebec - Canada # 1',
#   "Jam - Smucker's - * Bonus 15 Points M",
#   'Crunchy bars',
#   'Plates',
#   'Ice Cream With Vanilla',
#   'Ice Cream With Vanilla',
#   'Honey',
#   'Slim Frozen Butter Chicken Pizza - Worldwide Flavors - See Varieties in Store',
#   'Coffee Cartridges - Unnamed - See Varieties In Store',
#   'Toothbrush - Extra Clean - Saturday, August 31 only.- Limit of 4 - 99 ¢ The rest of the week or by item outside the limit',
#   'Red Peppers of Fields - Quebec - 50% off',
#   'Coffee in K-Cup buckets - McCafe',
#   'Laundry Detergent - Pods',
#   'Licorice - NIBS - See Varieties in-store',
#   'nectarines',
#   'Refrigerated dessert',
#   'Refrigerated Beverage - Oasis Morning - See Varieties In Store',
#   'Capillary Products - Whole Blends - See Varieties in-store',
#   'Chopped of turkey chest',
#   'Peanut Butter - Creamy - Saturday, February 16th only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   'Cantaloup - from the United States',
#   'Cookies - Goglu',
#   "Frozen fruit - President's choice - See in-store variety",
#   'Mined with ham',
#   'raisin bread',
#   'Licorice - NIBS - See Varieties in-store',
#   'Litchis - Imported',
#   'Instant Rice - See Varieties In Store',
#   'Antisodorific or deodorant',
#   'Green grapes without glitches - Category # 1',
#   'Dishwasher - View Varieties In store',
#   'Very big green peppers - from Quebec',
#   'Grain Coffee - St-Denis Burning - View Varieties in Store - * Bonus 45 Points M',
#   'Refrigerated fruit juice - health break',
#   'Cereal - Alpha-Bits - 50% discount',
#   'Rice - Quick & Good - View Varieties in store',
#   'Soybean spread',
#   'Green grapes without glitches - California - Category # 1',
#   'Peanut Butter - Natural Crunchy - Saturday 8th and Sunday December 9th, only - Limit of 4 - $ 4.99 The rest of the week or by article out of bounds',
#   'Acetaminophen - Regular 325 mg',
#   'Fresh turkey chest boneless',
#   'Turkey skewers with vegetables',
#   'Acetaminophen - Regular 325 mg',
#   'Yogurt - Classical',
#   'Beer - Buy 2 Caisses and get a $ 15 reduction on your other groceries',
#   'Sliced charcuterie - see varieties in store',
#   'Ground Coffee - Gourmet',
#   'Grape bread with cinnamon - pom',
#   'Meal Set - Stackers Lunch Mate',
#   'Meringue lemons tart',
#   'Korean brown pears - from China',
#   'Frozen duck - Category Utility',
#   'Capillary Color - Beautiful Color',
#   'Fresh pork net - Under vacuum packaging',
#   'Soup - Gastronomy of the day',
#   'Refrigerated dessert',
#   "Seafood Broth Less salt - Campbell's",
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Lemons',
#   'Jam, jelly, marmalade, spread - see varieties in store',
#   'Frozen waffles - EGGO',
#   'Flooded pizza - thin and crispy or blue menu - see varieties in store',
#   'Treats for Dogs - Tarticking Slices',
#   "Cream 35% - Ultra'Crème - * Bonus 30 Points M In purchase of 2",
#   'mushrooms of Paris',
#   'Instant Gruau - See Varieties In Store',
#   'Brown eggs - Gros Caliber',
#   'Spread',
#   'Chicken for Chinese fondue',
#   'Croissant',
#   'Pasta without wheat / gluten free',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Training panties',
#   'Mousse',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Chou-flower - the United States and / or Mexico and / or Spain - Category # 1',
#   'Puree of organic apples - the choice of the president',
#   'Pure maple syrup',
#   'Frozen Pizza - Giuseppe',
#   'Chocolates - Turtles - Saturday 23 and Sunday November 24th only!- limit of 4 - $ 8.99 the rest of the week or by article out of bounds',
#   'Hygienic buffers - Pearl',
#   'Seafood flavored with crab',
#   'Chocolate treatments - Mini',
#   'Organic red pepper - from Spain or Mexico',
#   'Preparation for infants A + 2',
#   'Ice Cream With Vanilla',
#   'Frozen thin crust pizza - Ristorante - See in store varieties',
#   'Sliced charcuterie',
#   'Sliced charcuterie - see varieties in store',
#   'Fresh pickles - from Quebec and / or Canada',
#   'Frozen Waffles - EGGO - * Bonus 25 Points M',
#   'Big White Eggs, Grade A - Saturday 7th and Sunday 8 July Only - Limit of 2 - $ 2.49 The rest of the week or by item outside the limit',
#   'Apple juice - see varieties in store',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   "Frozen fruit - President's choice - See in-store variety",
#   "Jam - Smucker's",
#   'Chocolate',
#   'Paper towels',
#   "Chocolate and Hazelnut Spread - President's Choice",
#   'Preparation for Infants - Good Start',
#   'Ice cream',
#   "Frozen fruit - President's choice - See in-store variety",
#   'Coffee in K-Cup buckets - see varieties in store',
#   'Yogurt to drink - Danactive - See in store varieties',
#   'Iced tea - limit of 4 - $ 3.99 per additional item',
#   'Plain flour',
#   'Ice Dessert - Classical - Limit of 2 - $ 3.49 per additional item',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Sliced charcuterie - see varieties in store',
#   'Baguette - See Varieties In Store',
#   'Refrigerated fruit juice - see varieties in store',
#   'Natural Source Water - Pure Life',
#   'Smoked sausages coated with frozen dough - Original - * 50 Points Bonus m',
#   'Mounted coffee - Traditional',
#   'Solid Turkey - Natural Selections',
#   'Cereal - Special K - View Varieties in-store',
#   'chopped beef, skinny',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Colorful cabbage salad',
#   'Rouge delicious apples - from the United States',
#   'Bacon - Original',
#   'Provolone cheese',
#   'Acetaminophen - Regular 325 mg',
#   'Frozen fries potatoes - Superfries',
#   "K-Cup coffee buckets - President's choice",
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Frozen Whipped Flooring - Cool Whip - Best Prices year',
#   'Multiple Packaging Chocolate - Kat Kit',
#   'Lozenges',
#   'Instant rice',
#   'Iced tea',
#   'Green grapes without biological seeds - the United States - Category # 1',
#   'Crunchy bars - Special K',
#   'Rice - Quick & Good - View Varieties in store',
#   "Peppers - Bick's - View varieties in store - * Bonus 20 points m",
#   'Frozen Pizza - Trabec',
#   'Cheese - mozzarellissima',
#   'Perfume enhancer for laundry - unstopable',
#   'Refrigerated cashew drink',
#   "Frozen fruit - President's choice - See in-store variety",
#   'Sliced Charcuterie - See Varieties In-store',
#   'Fresh pasta - see varieties in store',
#   'Apples Cortland A.C. - Du Québec - Canada of Fantasy',
#   'Acetaminophen - Complete - Cold, Cough and Influenza',
#   'Frozen Whipping Pack - Cool Whip',
#   'Cranberry Infused Water - PACT - See Varieties In stock',
#   'Cheese Sticks - Ficello',
#   'Peanut Butter - All Natural',
#   'Cereal - Cinnamon Croque',
#   'Dinner on the thumb',
#   "Jelly - Smucker's",
#   'Sparkling water - Pure Life - See in store varieties',
#   'Fresh Full Chicken - Pack of 2 Units',
#   'Layers - The Choice of President',
#   'Ice cream - Cremerie style - See in store varieties',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Chicken Tournedos with frozen bacon',
#   'Omega 3',
#   'Omega-3 - Select',
#   'Beer - $ 9 Discount for 2 Caisses',
#   'Honey',
#   'Ice Cream With Vanilla',
#   "Sliced Cheese - P'tit Québec",
#   'Yogurt - Mediterranean',
#   'Draught beer',
#   'Tartinade Hoummos',
#   'Lawyers Hass - Mexico',
#   'Chicken, chest, boneless, skinless',
#   'Organic food for baby',
#   'Licorice - NIBS - See Varieties in-store',
#   'Lipstick - Exhibitionist',
#   'Ice Cream With Vanilla',
#   'Acetaminophen - Regular 325 mg',
#   'Hygienic paper - Fluff',
#   'Peanut Butter - Creamy and Light - Saturday 29 and Sunday 30 September only - Limit of 4 - $ 4.99 The rest of the week or by item outside the limit',
#   'Disinfecting wipes',
#   'Antiperspirants - see varieties in store',
#   'Training Panties - Easy UPS',
#   'Antiperspirants - Saturday 13 and Sunday, October 14th only - Limit of 4 - $ 3.49 The rest of the week or by article out of bound',
#   'Instant Coffee - Rich - Saturday 24th and Sunday 25 November Only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   'Biological Hass Lawyer - Mexico',
#   'Antiperspirant - * Except: Platinum',
#   'Baby food - see varieties in store',
#   'Licorice - NIBS - See Varieties in-store',
#   'Gluten-free crackers - Breton - See in store varieties',
#   'Lemons',
#   'Honey',
#   'Cake Mix - Classic',
#   'Bleach',
#   'Extra Beer - Buy 2 Caisses and get $ 15 off your grocery basket',
#   'Big White Eggs, Grade A - Saturday 2 and Sunday February 3rd - Limit of 2 - $ 2.49 The rest of the week or by article out of bound',
#   'Croissant paste',
#   'CREAM 10%',
#   'Chocolate treats',
#   'Licorice',
#   'Frozen pizza',
#   'Frozen Pizza - Giuseppe',
#   'U-shaped buffers',
#   'Chocolate treats - Aero',
#   'Hamburger breads - POM - * Bonus 20 points M to the purchase of 2',
#   'Ice Cream - Cremerie Style',
#   'Beet of Card Rainbow - Quebec',
#   'Semi-Boneless Smoked Ham - Olde Fashioned',
#   'Frozen thin crust pizza - Ristorante - See in store varieties',
#   'Unparalleled drinks - Coca-Cola or Pepsi - Saturday 28 and Sunday 29 September only.- Limit of $ 4 - $ 4.49 per additional item - $ 4.99 The rest of the week',
#   'Lemons',
#   'Yogurt skyr',
#   'Frozen waffles - EGGO',
#   'Frozen breaded chicken burgers - pub style - limit of 4 - $ 6.99 per additional item',
#   'Ice Cream With Vanilla',
#   'Chocolate',
#   'Cookies - Maple Leaf',
#   'Chickpeas, canned',
#   'Rice Takers, Baby Biscotties - Baby Mum-Mum',
#   'Pasta - See Varieties In stock',
#   'Liquid soap for hands',
#   'Lemons',
#   'Frozen Pizza - Casa di Mama - Saturday 27 and Sunday, October 28th only - Limit of 4',
#   'Frozen Chicken Strips - Pub Recipe',
#   'Frozen Whipping Pack - Cool Whip',
#   'Cookies - weather - see varieties in store',
#   'Muffins - Market Delights',
#   'Cookies - Saturday 15 and Sunday 16 December only - Limit of 4 - $ 2.99 The rest of the week or by article out of bound',
#   'Wiper - Green',
#   'Chocolate',
#   'Cake Mix - Supermist',
#   'sweetened condensed milk',
#   'Sachered Beverage Mix - Light Crystal',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Antiperspirants - see varieties in store',
#   'Yogurt - Classical',
#   'Corn syrup - Lily White',
#   'Tissue Paper - Limit of 4 - $ 6.99 per additional item',
#   'White eggs, category A - Saturday 14 and Sunday 15 September only - Limit of 2 - $ 2.29 per additional item - $ 2.49 The rest of the week',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Dishwasher - View Varieties In store',
#   'Frozen breaded fish sticks - See in store varieties',
#   'Vitamin C - 500 mg',
#   'vegetables soup',
#   'Shampoo - See Varieties In Store',
#   'Frozen Farcie Crust Pizza',
#   'spinach babies',
#   'Gassed source water',
#   'Gluten-free crackers - Breton - See in store varieties',
#   'Italian Charcuterie - See Varieties In Store',
#   "Instant Coffee - Taste's Choice - See Varieties In Store",
#   'Grain Coffee - Mont-Royal Burn',
#   'Chewing gum',
#   'Fruit snack - GOGO SQUEZ - Lower price of the year',
#   'Pellets - see varieties in store',
#   'Hygienic paper - limit of 4 - $ 8.99 per additional item',
#   'Styling foam',
#   'Apple Compote - Free',
#   'Sausages - Simply Good',
#   'Cereal - Alpha-bits',
#   'Bagel frozen cocks',
#   'Almond Butter - Blue Menu',
#   'Ice Cream With Vanilla',
#   'Cheese snacks - Nanö',
#   'Litchis - Imported',
#   'Cream Cheese - Philadelphia - See Varieties In stock',
#   'Battery toothbrush - see varieties in store',
#   'Sliced charcuterie - see varieties in store',
#   'Frozen duck - Category Utility',
#   'Sliced charcuterie - see varieties in store',
#   'Sliced charcuterie - see varieties in store',
#   'Cereal - Special K',
#   'Capillary Color - Feria',
#   'quinoa',
#   'Refrigerated Beverage - Oasis Morning - See Varieties In Store',
#   'Chips - Unnamed',
#   'Gas Drink - See Varieties In Store',
#   'Gas Drink - Coke Diet',
#   'Cats Food - Fancy Feast - View Varieties in-store',
#   'Pâté with three frozen meats',
#   'yellow onions',
#   'Antiperspirants - see varieties in store',
#   "Chocolate treatments - Hershey's - View Varieties in-store",
#   'Cookie mix',
#   'Fruit Drink - See Varieties In Store',
#   'Hygienic paper - Fluff',
#   'Provolone cheese',
#   "Organic Drink - President's Choice - See Varieties In-store",
#   'Brussels sprouts',
#   'Capillary Products - Frunts - Saturday, November 16th only - Limit of 4 - $ 2.99 The rest of the week or by article out of bound',
#   'Crustles - Stax - * Bonus 25 Points M Within Buying 3',
#   'Frozen Meal - Slimming Kitchen',
#   "Frozen Beef Bouballs - President's Choice",
#   'Ice cream',
#   'Sliced charcuterie - see varieties in store',
#   'Hygienic buffers - Pearl',
#   'Max batteries',
#   'Cretons - Buy 2 and get the third for free for free',
#   '100% refrigerated juice mix - see varieties in store - * Bonus 20 points m',
#   'Yogurt Nature Bio',
#   'Ice Dessert - Classic - See Varieties In Store',
#   'chopped beef, skinny',
#   'tomatoes',
#   'Cereal - Special K',
#   'Cut Carrots (Cocktail) Organic',
#   'Disinfecting wipes',
#   'Crackers - Saturday 18 and Sunday, May 19th only.',
#   'Pasta - See Varieties In stock',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Frozen Pizza - See Varieties in Store - * Bonus 20 Points M',
#   'Fridges',
#   'Dietal drink',
#   'Chia seeds',
#   'Velvety peanut butter',
#   'Sliced salami',
#   'Capillary products',
#   'Batteries - Saturday, 22 and Sunday 23 June only.- Limit of 4 - $ 13.79 The rest of the week or by item outside.',
#   'Frozen Pancakes - EGGO - * Bonus 15 Points M',
#   'Skimmed milk - finely filtered',
#   'Ice Dessert - Classic - See Varieties In Store',
#   'Strike Milk - See Varieties In Store',
#   'Skim milk - Purfiltre',
#   'Frozen waffles - EGGO',
#   'Licorice',
#   'Pale tuna',
#   'Crunchy peanut butter',
#   'Frozen duck - Category Utility',
#   'Hygienic paper - Fluff',
#   'mozzarella cheese',
#   'Probiotic Yogurt - Activia',
#   'Greek Greek Yogurt - See Varieties In Store',
#   'Hygienic paper - Fluff',
#   'Meal kit - see varieties in store',
#   'Yogurt Nature Bio',
#   'Biscuits - Bear Paws - Buy 2 and Get FREE 1 Bear Craquins Paws',
#   'Frozen Chicken Chest Burgers - Pub Style',
#   'Butter',
#   'Hygienic paper - Original - Saturday 27 and Sunday, July 28th only.- Limit of 4 - $ 5.99 The rest of the week or by item outside the limit',
#   'Frozen fish fillets - Japd by the day - see varieties in store',
#   'Chip',
#   "Chocolate and Hazelnut Spread - President's Choice",
#   'Apple juice',
#   'Probiotic Kefir - Original',
#   'Ice Dessert - Classic - See Varieties In Store',
#   'Chickpeas, canned',
#   'Rinse Agent - Jet Dry - * Bonus 40 Points M',
#   "Instant Coffee - Taste's Choice - * Bonus 20 Points M",
#   'Spread',
#   'Facial Moisturizers - Complete',
#   'Spread',
#   'Frozen Hot Chicken Pâté',
#   'Campaign Pipe - See Varieties In Store',
#   'Cheese without lactose - see varieties in store',
#   'Nature chicken strips',
#   'Frozen Eaglefin Nets - Market Cups',
#   'Juices - Assorted flavors',
#   'Yogurt',
#   'Max batteries',
#   'fruit yogurt',
#   'Spread',
#   'White potatoes - from Quebec',
#   'Capillary dye - image',
#   'CREAM 10%',
#   'Yogurt - Classical',
#   'Ice Cream With Vanilla',
#   'Cheese snack',
#   "Jam - Smucker's - * Bonus 15 Points M",
#   'fruit yogurt',
#   'Licorice',
#   'Liquid soap for hands',
#   'Biological Hass Lawyer - Mexico',
#   'Cereal - See Varieties In store',
#   'Flavored pale tuna',
#   'Mousse',
#   'Frozen fish sticks',
#   'Ice Cream With Vanilla',
#   'Submarine breads',
#   'Peanut butter - creamy and light - Saturday 17 and Sunday 18 August only.- limit of 4 - $ 4.99 the rest of the week or by item outside the limit',
#   'Rice',
#   'Peanut Butter - All Natural - Sea Salt',
#   'Oil jelly',
#   'Peanut Butter',
#   'Cookie mix',
#   'CREAM 10%',
#   'Refrigerated cashew drink',
#   'Ice Dessert - Classic - See Varieties In Store',
#   'Frozen thin crust pizza - Ristorante - See in store varieties',
#   'Fridges Ice - Popsicle',
#   'Sliced charcuterie - see varieties in store',
#   'Soybean Drink - Natur-A',
#   'Cream 35%',
#   'Frozen garlic bread',
#   'nectarines',
#   'Tart crust Two crusts with deep vegetable pies frozen',
#   'Honey - Unnamed',
#   'Silved charcuteries - Buy 3 and get 30 air miles as a premium.Friday, December 7th only.',
#   'Cheese - Bocconcini',
#   'Tissue Paper - Choice of President - Limit of 4 - $ 5.99 per additional item',
#   'Syrup for chocolate milk - Nesquik',
#   'Liquid soap',
#   'Salad Sauce - Miracle Whip',
#   'Lemons',
#   'Chopped chicken - blue menu',
#   'Hygienic buffers - Pearl',
#   'Middle Green Cabbage - Quebec - Canada # 1',
#   'Disinfecting wipes',
#   'Capillary color - Beautiful Color - Saturday 27 and Sunday, July 28th only.- Limit of 4 - $ 5.99 The rest of the week or by item outside the limit',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Fridges',
#   'Coffee in organic and fair grains',
#   'GASED MINERAL WATER',
#   'Rice',
#   'waffles',
#   'Hygienic paper - limit of 4 - $ 7.99 per additional item',
#   'Hot medicine for coughs and colds - neocitran - see varieties in store',
#   'Cheese - mozzarellissima',
#   'Slicing cheese',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Cuvette cleaner',
#   'Skin care products',
#   'UHT milk - Chokéo - See in store varieties',
#   'Cat Food - Friskies',
#   'Biscuits - Snak PAKS',
#   'Margarine with lawyer oil',
#   'Cereal - Special K',
#   'Rouge delicious apples - from the United States',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Tissue Papers - Pack of 6 Boxes',
#   'Bar - Protilife - See Varieties in-store',
#   'Preparation for infants A + 2',
#   'Frozen Pizza - Trabec',
#   "Frozen Chicken Wings - President's Choice",
#   'Gas Drink - Coke - See Varieties in Store - 50% off',
#   'Acetaminophen - Regular 325 mg',
#   'Grape Bread - Old Moulin',
#   'Sour cream',
#   'Roman lettuces',
#   'Mango Ataulfo - Mexico',
#   'Preparation for infants A + 2',
#   'Mined with ham',
#   'Iced tea',
#   'Rice',
#   'Red Mango - Imported',
#   'Ice Cream With Vanilla',
#   'Beans',
#   'Hygienic buffers - Pearl',
#   "Thin and crisp pizza - President's choice",
#   'Sandwich or snack bags - Unnamed',
#   'Creamy and light peanut butter',
#   'Frozen Pizza - Ristorante - View Varieties in-store - Limit of 3 - Saturday 7 and Sunday December 8th',
#   'Peanut Butter - Natural Crunchy - Saturday, November 10th Only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Red Delicious Apples - Quebec - Canada of Fantasy',
#   'Peanut Butter - Blue Menu',
#   'Table towels - Unnamed',
#   'Ice Sweets - Drumstick',
#   'Laundry Detergent - Pods',
#   'Chocolate treats - Kisses',
#   'Milk 2% lactose-free',
#   'cannelloni',
#   'Cookies - Saturday, October 19th only.- Limit of 4 - 3.49 by additional article',
#   'Natural peanut butter with salt',
#   'Snatcher',
#   'Rouge delicious apples - from the United States',
#   'Peanut Butter - Natural Crunchy - Saturday 29th and Sunday 30 December only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   "Mini-Cakes - Annette's - See Varieties in-store",
#   'Raisins Tomatoes - Quebec and / or Mexico - Category # 1',
#   'Red or black plums',
#   "Frozen vegetables - President's choice",
#   'Turkey Hachis - Irresistibles, Wellness',
#   'Yogurt - Classical',
#   'Cottage cheese',
#   'chopped beef, skinny',
#   'Juice at 100% - Nutrisource - View Varieties in-store',
#   'PREPARATION FOR INFANTONS - MORE START More',
#   'Disinfecting wipes',
#   'Powder preparation with Omega for Nurtures - The Choice of President - See Varieties in Store - at Maxi & Cie only',
#   'Peanut butter - crunchy - Saturday 7 and Sunday, December 8th only!- limit of 4 - $ 4.99 the rest of the week or by article out of bounds',
#   'Drink - Natur-A - See Varieties in store',
#   'Rice - Quick & Good - View Varieties in store',
#   'Hygienic paper - Fluff',
#   'Toothpaste - 3D White',
#   'Frozen chicken breast fillets',
#   'Biological yogurt',
#   "Instant Coffee - Taste's Choice - See Varieties In Store",
#   'Panated cheese sticks',
#   "Peppers - Bick's - View varieties in store - * Bonus 20 points m",
#   "Barbecue chicken - President's choice",
#   'Sliced Charcuterie - See Varieties In-store',
#   'Biological yogurt',
#   'Green apples, Granny Smith',
#   'Frozen Pork Back Côtes - Save $ 5.11',
#   'fisheries',
#   'Ice Cream - Lactose Free',
#   'Yellow greenhouse peppers - from Canada and / or Mexico and / or Honduras',
#   'Biological Hass Lawyer - Mexico',
#   'Chips - Saturday 27 and Sunday 28 April only - Limit of 4 - $ 4.49 The rest of the week or by article out of bounds',
#   'Apples - Quebec and / or the United States and / or imported - see varieties in store',
#   'Red Potatoes - From Quebec - Canada No 1',
#   'Juices - Nutrisource',
#   'Evaporated Milk - Carnation',
#   'Peanut Butter - All Natural',
#   'Skin care products',
#   'Frozen Chicken Chest Burgers - Premium',
#   'Jam',
#   'Chocolate bars',
#   'broccoli',
#   'Ice Sweets - Drumstick - View Varieties in-store',
#   'Apples naturally imperfect, category # 2 - Quebec',
#   'Frozen Whipped Flooring - Cool Whip - Best Prices year',
#   'Bars',
#   'Madeleines',
#   'Ice Cream With Vanilla',
#   'Fragrant oil',
#   'Beer - Mexico Beers - * Bonus 50 Points M',
#   'Frozen waffles - EGGO',
#   'Teaser',
#   'Tartier Cheese - Cheez Whiz',
#   'Refrigerated Beverage - Oasis Morning - See Varieties In Store',
#   'Cats Food - Cat Chow - Save $ 1.50',
#   'Yogurt',
#   'Collagen - Original Formula',
#   "Pale tuna - Ocean's",
#   'Cookie mix',
#   'Organic Beverage - Natur-A',
#   'Frozen Oven Lift Pizza - See Varieties In Store',
#   'Celery - the United States and / or Mexico - Category # 1',
#   'Acetaminophen - Regular 325 mg',
#   'Acetaminophen - 500 mg Fast Action',
#   'Partially skimmed milk 1% - Purfiltr',
#   'tortillas',
#   'Peanut Butter - All Natural',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Energy Bars - Clif - View Varieties In-store',
#   'English cucumber - Mexico - Category # 1',
#   'Small White Potatoes - From Quebec - Canada No 1',
#   'fennels',
#   'Frozen Pizza - Slim and Crispy Crust - Saturday 29th and Sunday 30 June Only - Limit of 4 - $ 4.99 per additional item',
#   'Cookies - Maxi Fruits - See Varieties In Store',
#   'Pea',
#   'Peanut Butter - Whipped',
#   'Roast French unparalleled',
#   'Sliced charcuterie - see varieties in store',
#   'Lasagna Pasta - Smart',
#   'Coffee in K-Cup buckets - see varieties in store',
#   'Chocolate bars',
#   "Cream 35% - Ultra'creme",
#   'Tomatoes on the vineyard - of Quebec',
#   'Green Beans - Mexico or Guatemala',
#   'entire turkey',
#   'Toothpaste - MaxFris - Saturday 17 and Sunday 18 August only.- Limit of 4 - 99 ¢ The rest of the week or by item outside the limit',
#   'rhubarbes',
#   'Chocolate Tablet - Swiss Classic - View Varieties in Store - Best Prices Year',
#   'Fresh Atlantic salmon fillet',
#   'Chocolate Tablets - Lindor',
#   'Lemons',
#   'Refrigerated Beverage - Oasis Morning - See Varieties In Store',
#   'Sliced charcuterie - Splendido - See in store varieties',
#   'Frozen Pacific Wild Pink Salmon Fillet',
#   'Black Forest Smoked Ham Without Nitrite Sliced',
#   'Sliced charcuterie - see varieties in store',
#   'oka cheese',
#   'Yogurt to drink - Iögo',
#   'Red Grapes without glitches - California - Category # 1',
#   'Greek Yogurt - Oikos',
#   'Frozen breaded chicken burgers - pub style - limit of 4 - $ 6.99 per additional item',
#   'Smoked sausages coated with frozen dough - Original - * 50 Points Bonus m',
#   'Soup - Vegetables',
#   'Antiperspirants - see varieties in store',
#   'All-purpose flour - embodie xxx',
#   'Frozen Pizza - Trabec',
#   'Cat Food - Friskies',
#   'Meatballs',
#   'Cookies - Maxi Fruits - See Varieties In Store',
#   'Jam - blue menu - see varieties in store',
#   'Tartier Cheese - Cheez Whiz',
#   "Fridges - Hershey's",
#   'Bars - Special K - View Varieties In-store',
#   "Frozen meal - President's choice - See Varieties in-store",
#   'Fresh chicken wings',
#   'Provolone cheese',
#   'Raisins and cinnamon bread',
#   'Frozen Pancakes - EGGO - * Bonus 15 Points M',
#   'Green Onions - Mexico',
#   'Mascara - voluminous',
#   'Peanut butter - Natural crunchy - Saturday 23 and Sunday, November 24th only!- limit of 4 - $ 4.99 the rest of the week or by article out of bounds',
#   'Biscuits - see varieties in store',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Frozen lemonade',
#   'Soup - Chunky',
#   'Deodorant',
#   'Tea in sachets - Orange PEKOE',
#   'Veggie slices',
#   'Dry Sausage - Craftsman - View Varieties In-store',
#   'Fruit juice',
#   'Chocolate syrup - Nesquik',
#   'Peanut Butter - Natural Crunchy - Saturday, November 10th Only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   'Frozen chicken wings',
#   'Craquins - Breton Artisanal',
#   'Smoothie - Iögo - View varieties in store <',
#   'Peanut Butter',
#   'Refrigerated cashew drink',
#   'Sliced charcuterie - see varieties in store',
#   'Antiperspirants - see varieties in store',
#   'cracker',
#   'Retouch-Research - Root Touch-Up',
#   'Shampoo - See Varieties In Store',
#   'Peanut Butter - Crunchy - Saturday 8th and Sunday 9 December only - Limit of 4 - $ 4.99 The rest of the week or by article out of bound',
#   'Shampoo - See Varieties In Store',
#   'Laundry Detergent in Capsules - Pods',
#   'pork, nets',
#   'Frozen Oven Lift Pizza - See Varieties In Store',
#   "Fruit Cocktail - President's Choice",
#   'Grignotignes - See Varieties In Store',
#   'Cookies - Maxi Fruits - See Varieties In Store',
#   'Craquins - Vinta - See Varieties In stock',
#   'Mouthwash - Classic',
#   'Partially skimmed milk 2%',
#   'Frozen waffles - EGGO',
#   'Yogurt Balkan - Original - See Varieties In stock',
#   'Litchis - Imported',
#   'Chicken, chest, boneless, skinless',
#   'Meal set',
#   'Smoke chicken sausages',
#   'Frozen sailor shell',
#   'Beer - Mexico Beers - * Bonus 50 Points M',
#   'Toothbrush - Extra Clean - Saturday, August 31 only.- Limit of 4 - 99 ¢ The rest of the week or by item outside the limit',
#   'Energy Bar - See Varieties In Store',
#   "Honey - President's Choice - See Varieties In Store",
#   'Snatcher',
#   'Hand Soap - See Varieties In Store',
#   'Green Beans - United States',
#   'Jam',
#   'Ice Cream With Vanilla',
#   'Chocolate Breaks - The Decadent',
#   'Refrigerated dessert',
#   'Ice Cream With Vanilla',
#   'Frozen Whipped Flooring - Cool Whip - Best Prices year',
#   'Probiotic Drink - Danactive',
#   'Cereal - See Varieties In store',
#   'Hygienic stamps - Saturday 20th and Sunday 21 April only - Limit of 4 - $ 7.99 The rest of the week or by article out of bound',
#   'Appetizer - * bonus 35 points m to buy 2',
#   'Frozen fries potatoes - Superfries',
#   'White eggs',
#   'Probiotic Drink - Danactive',
#   'Frozen thin crust pizza - rustico',
#   'Ice Cream With Vanilla',
#   'Organic food for baby',
#   'Laundry Detergent - Ultra Packs - Saturday 8th and Sunday 9 September Only - Limit of 4 - $ 3.99 The rest of the week or by item outside the limit',
#   'Cupcakes',
#   'Cookies - Goglu',
#   'Max batteries',
#   'Parchment paper',
#   'UHT milk - Chokéo - See in store varieties',
#   'Hearts of Romaine Lettuce - Quebec - Ordinary price: $ 3.49',
#   'Crunchy bars - Special K',
#   'Toothpaste - Pro-Health',
#   'Frozen Pizza - Casa di Mama - Saturday 27 and Sunday, October 28th only - Limit of 4',
#   'Coffee Cream - See Varieties In Store',
#   'Gas Drink - 7-Up, 7-Up Diet',
#   'Frozen Whipped Flooring - Cool Whip - Best Prices year',
#   'Fondal Cheese Preparation - Velveeta - * Bonus 30 Points M',
#   'Fresh chicken breast boneless, skinless',
#   'Hot Chocolate Mix - Carnation',
#   'Baby Baby Toiletries - See Varieties In Store',
#   'Yogurt',
#   "Frozen meal - Marie Callender's",
#   'Liver block - View varieties in store',
#   'Cranberry cocktail',
#   'Campaign Pipe - See Varieties In Store',
#   'Coffee in Capsules - Nabob',
#   'Licorice',
#   'Celery - the United States and / or Mexico - Category # 1',
#   'Wind flights',
#   'Cereal - Buy 1 and get 1 GENERAL GENERAL MILLS LUCKY FRUITY CHARMS Box (340 g), Trix (303 g).Value of $ 3.99',
#   'Pediatric nutritional supplement - Pediasure - See varieties in store - at Maxi & Cie only',
#   'Frozen puff pastry',
#   'Cookies - Goglu',
#   'Yogurt - Classical',
#   "Cheese - Sir Laurier d'Arthabaska",
#   'Refrigerated Orange Juice, with Pulps - Premium - Limit of 4 - $ 3.99 per additional item',
#   'CREAM 10%',
#   'Peanut Butter',
#   'Honey - Unnamed',
#   'Ice bars - Saturday, January 26th only.- Limit of $ 2 - $ 2.99 per additional item.',
#   'Yogurt - Classical',
#   'Peanut Butter - Natural - See Varieties In Store',
#   'Cookies - Maxi Fruits - See Varieties In Store',
#   "Jam - Smucker's - * Bonus 15 Points M",
#   "Mini-Cakes - Annette's - See Varieties in-store",
#   'Mascara - Great Lash',
#   'Biological Fisheries - California - Category # 1',
#   'Chips - Saturday 17 and Sunday 18 August only.- $ 3.79 the rest of the week',
#   "Cheese Bar - P'tit Québec - View Varieties in-store",
#   'cracker',
#   "Wiper - President's Choice",
#   'PEKOE orange tea in sachets',
#   'cracker',
#   'Nail Polish - Xtreme Wear',
#   'Hygienic paper - Selection',
#   'mozzarella cheese',
#   'Lash Liquid Detergent - Simply - Saturday 12th and Sunday May 13th Only - Limit of 4 - $ 3.99 The rest of the week or by article out of bounds',
#   'Frozen fruit',
#   'Pellets - see varieties in store',
#   'Yogurt to drink - Kik - View Varieties in store',
#   'Cats Food - Proactive Health',
#   'Gluten-free walnut butter - NUTS TO YOU - View varieties in store',
#   'banana',
#   'Frozen breaded chicken tabs',
#   'Chocolate Tablets - Swiss Classic',
#   'Hamburger breads - see varieties in store',
#   'cracker',
#   'Wiper - Green',
#   'PEKOE orange tea in sachets',
#   'Cookies - Goglu',
#   'Instant Rice - Express Bistro - View Varieties in-store',
#   'Chocolate treats - Mini Eggs',
#   'Chewing gum - 4 box packs',
#   'Soup - Chunky',
#   "Frozen fruit - President's choice - See in-store variety",
#   'Frozen Pizza - Trabec',
#   'Multivitamins - Men 50+ - Saturday 27 and Sunday 28 April only - Limit of 4 - $ 16.99 The rest of the week or by article out of bound',
#   "Frozen Cake - Deep'n Delicious",
#   'Peanut butter - all natural - Saturday 15 and Sunday 16 September only - limit of 4 - $ 4.99 the rest of the week or by article out of bounds',
#   'Disinfecting wipes',
#   'Refrigerated dessert',
#   "Drink - President's Choice",
#   'Appetizer - Méli-Mélo',
#   'Jam, marmalade or spread',
#   'Sliced salami',
#   "Frozen Cake - Deep'n Delicious",
#   'cantaloups',
#   'Soap',
#   'Whipped peanut butter',
#   "Jam - Smucker's",
#   'banana',
#   'Pâté with frozen braised beef',
#   'Cookies - Maple Leaf',
#   'Apple Compote - Free',
#   'Frozen Whipped Flooring - Cool Whip - Best Prices year',
#   'Biscuits - see varieties in store',
#   'Fresh chicken breast boneless, skinless',
#   'Teaser',
#   'Pasta',
#   'Frozen duck - Category Utility',
#   'Peanut Butter',
#   'Refrigerated Juice Mix - Tropics - See Varieties In-store',
#   ...]}

# %%
if data.loc[data['id'] == row['product_id'], 'name'].values[0] != row['name']:
